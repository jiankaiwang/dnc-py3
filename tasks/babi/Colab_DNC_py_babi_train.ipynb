# %%
import os
import time

# %% [markdown]
# # Reference
#
# * https://github.com/Kajiyu/dnc-py3.git
# * https://github.com/Mostafa-Samir/DNC-tensorflow.git

# %% [markdown]
# # Source Code

# %%
# !git clone https://github.com/Kajiyu/dnc-py3.git
# !git clone https://github.com/Mostafa-Samir/DNC-tensorflow.git
# Out:
# Cloning into 'dnc-py3'...
# remote: Enumerating objects: 317, done.
# remote: Total 317 (delta 0), reused 0 (delta 0), pack-reused 317
# Receiving objects: 100% (317/317), 43.27 MiB | 23.24 MiB/s, done.
# Resolving deltas: 100% (197/197), done.
# Checking out files: 100% (115/115), done.
# Cloning into 'DNC-tensorflow'...
# remote: Enumerating objects: 641, done.
# remote: Total 641 (delta 0), reused 0 (delta 0), pack-reused 641
# Receiving objects: 100% (641/641), 89.78 MiB | 28.12 MiB/s, done.
# Resolving deltas: 100% (317/317), done.
# Checking out files: 100% (56/56), done.

# %%
# !mv ./DNC-tensorflow/tasks/babi/checkpoints ./dnc-py3/tasks/babi/

# %%
print(next(os.walk("./dnc-py3/tasks/babi/checkpoints"))[1])
# Out:
# ['step-500005']

# %% [markdown]
# # bABI

# %%
import os
import sys

sys.path.append(os.path.join(".","dnc-py3"))
from dnc.dnc import DNC

sys.path.append(os.path.join(".","dnc-py3","tasks","babi"))
from recurrent_controller import RecurrentController

import tensorflow as tf
import numpy as np
import pickle
import re

# %%
def llprint(message):
    sys.stdout.write(message)
    sys.stdout.flush()

# %%
def load(path):
    return pickle.load(open(path, 'rb'))

# %%
def onehot(index, size):
    vec = np.zeros(size, dtype=np.float32)
    vec[int(index)] = 1.0
    return vec

# %%
def prepare_sample(sample, target_code, word_space_size):
    """
    Input:
      sample: train or test data with np.array([{'inputs':[],'outputs':[]}])
      target_code: the end word in the inputs, here is '-'
      word_space_size: the word space, here is 159
    Output:
      [0]: input_vec with one-hot encoding as [batch_size=1, word_count, word_space_size]
      [1]: output_vec with one-hot encoding as the same with input_vec
           but replacing target_code with sample["outputs"]
      [2]: seq_len: word_count
      [3]: weights as [batch_size=1, word_count, 1] to mark target_code as 1.0,
           the other is zero
    """
    input_vec = np.array(sample[0]['inputs'], dtype=np.float32)
    output_vec = np.array(sample[0]['inputs'], dtype=np.float32)
    seq_len = input_vec.shape[0]
    weights_vec = np.zeros(seq_len, dtype=np.float32)

    target_mask = (input_vec == target_code)
    output_vec[target_mask] = sample[0]['outputs']
    weights_vec[target_mask] = 1.0

    input_vec = np.array([onehot(int(code), int(word_space_size)) for code in input_vec])
    output_vec = np.array([onehot(int(code), int(word_space_size)) for code in output_vec])

    return (
        np.reshape(input_vec, (1, -1, word_space_size)),
        np.reshape(output_vec, (1, -1, word_space_size)),
        seq_len,
        np.reshape(weights_vec, (1, -1, 1))
    )

# %%
prj_path = os.path.join(".","dnc-py3","tasks","babi")
ckpts_dir = os.path.join(".","dnc-py3","tasks","babi","checkpoints")
lexicon_dictionary = load(os.path.join(prj_path,"data","en-10k","lexicon-dict.pkl"))
question_code = lexicon_dictionary["?"]
target_code = lexicon_dictionary["-"]
test_files = []

for entryname in os.listdir(os.path.join(prj_path,"data","en-10k","test")):
    entry_path = os.path.join(os.path.join(prj_path,"data","en-10k","test", entryname))
    if os.path.isfile(entry_path):
        test_files.append(entry_path)

batch_size = 1

# %% [markdown]
# ## Starting Training

# %%
dirname = os.path.join(".","dnc-py3","tasks","babi")
ckpts_dir = os.path.join(dirname , 'checkpoints')
data_dir = os.path.join(dirname, 'data', 'en-10k')
tb_logs_dir = os.path.join(dirname, 'logs')

llprint("Loading Data ... ")
lexicon_dict = load(os.path.join(data_dir, 'lexicon-dict.pkl'))
data = load(os.path.join(data_dir, 'train', 'train.pkl'))
llprint("Done!\n")

batch_size = 1
input_size = output_size = len(lexicon_dict)
sequence_max_length = 100
word_space_size = len(lexicon_dict)
words_count = 256
word_size = 64
read_heads = 4

learning_rate = 1e-4
momentum = 0.9

from_checkpoint = None
iterations = 100000
start_step = 0
# Out:
# Loading Data ... Done!

# %%
graph = tf.Graph()
with graph.as_default():
    with tf.Session(graph=graph) as session:

        llprint("Building Computational Graph ... ")

        optimizer = tf.train.RMSPropOptimizer(learning_rate, momentum=momentum)
        summerizer = tf.summary.FileWriter(tb_logs_dir, session.graph)

        ncomputer = DNC(
            RecurrentController,
            input_size,
            output_size,
            sequence_max_length,
            words_count,
            word_size,
            read_heads,
            batch_size
        )

        output, memory_views = ncomputer.get_outputs()

        loss_weights = tf.placeholder(tf.float32, [batch_size, None, 1])
        loss = tf.reduce_mean(
            loss_weights * \
            tf.nn.softmax_cross_entropy_with_logits_v2(logits=output, \
                                                       labels=ncomputer.target_output)
        )

        summeries = []

        gradients = optimizer.compute_gradients(loss)
        for i, (grad, var) in enumerate(gradients):
            if grad is not None:
                gradients[i] = (tf.clip_by_value(grad, -10, 10), var)
        for (grad, var) in gradients:
            if grad is not None:
                summeries.append(tf.summary.histogram(var.name + '/grad', grad))

        apply_gradients = optimizer.apply_gradients(gradients)

        summeries.append(tf.summary.scalar("Loss", loss))

        summerize_op = tf.summary.merge(summeries)
        no_summerize = tf.no_op()

        llprint("Done!\n")

        llprint("Initializing Variables ... ")
        session.run(tf.global_variables_initializer())
        llprint("Done!\n")

        if from_checkpoint is not None:
            llprint("Restoring Checkpoint %s ... " % (from_checkpoint))
            ncomputer.restore(session, ckpts_dir, from_checkpoint)
            llprint("Done!\n")


        last_100_losses = []

        start = 0 if start_step == 0 else start_step + 1
        end = start_step + iterations + 1

        start_time_100 = time.time()
        end_time_100 = None
        avg_100_time = 0.
        avg_counter = 0

        for i in range(start, end + 1):
            try:
                llprint("\rIteration %d/%d" % (i, end))

                sample = np.random.choice(data, 1)
                input_data, target_output, seq_len, weights = \
                  prepare_sample(sample, lexicon_dict['-'], word_space_size)

                summerize = (i % 10 == 0)
                take_checkpoint = (i != 0) and (i % 1000 == 0)

                loss_value, _, summary = session.run([
                    loss,
                    apply_gradients,
                    summerize_op if summerize else no_summerize
                ], feed_dict={
                    ncomputer.input_data: input_data,
                    ncomputer.target_output: target_output,
                    ncomputer.sequence_length: seq_len,
                    ncomputer.input_mode: np.zeros((batch_size, seq_len, output_size)),
                    loss_weights: weights
                })

                last_100_losses.append(loss_value)
                # summerizer.add_summary(summary, i)

                if summerize:
                    llprint("\n\tAvg. Cross-Entropy: %.7f\n" % (np.mean(last_100_losses)))

                    end_time_100 = time.time()
                    elapsed_time = (end_time_100 - start_time_100) / 60
                    avg_counter += 1
                    avg_100_time += (1. / avg_counter) * (elapsed_time - avg_100_time)
                    estimated_time = (avg_100_time * ((end - i) / 100.)) / 60.

                    print("\tAvg. 100 iterations time: %.2f minutes" % (avg_100_time))
                    print("\tApprox. time to completion: %.2f hours" % (estimated_time))

                    start_time_100 = time.time()
                    last_100_losses = []

                if take_checkpoint:
                    llprint("\nSaving Checkpoint ... "),
                    ncomputer.save(session, ckpts_dir, 'step-%d' % (i))
                    llprint("Done!\n")

            except KeyboardInterrupt:

                llprint("\nSaving Checkpoint ... "),
                ncomputer.save(session, ckpts_dir, 'step-%d' % (i))
                llprint("Done!\n")
                sys.exit(0)
# Out:
# Building Computational Graph ... WARNING:tensorflow:From ./dnc-py3/tasks/babi/recurrent_controller.py:14: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# INFO:tensorflow:Summary name shape_inference/basic_lstm_cell/kernel:0/grad is illegal; using shape_inference/basic_lstm_cell/kernel_0/grad instead.
# INFO:tensorflow:Summary name shape_inference/basic_lstm_cell/bias:0/grad is illegal; using shape_inference/basic_lstm_cell/bias_0/grad instead.
# INFO:tensorflow:Summary name controller/interface_weights:0/grad is illegal; using controller/interface_weights_0/grad instead.
# INFO:tensorflow:Summary name controller/nn_output_weights:0/grad is illegal; using controller/nn_output_weights_0/grad instead.
# INFO:tensorflow:Summary name controller/mem_output_weights:0/grad is illegal; using controller/mem_output_weights_0/grad instead.
# Done!
# Initializing Variables ... Done!
# Iteration 0/100001
# 	Avg. Cross-Entropy: 0.1913008
# 	Avg. 100 iterations time: 0.03 minutes
# 	Approx. time to completion: 0.54 hours
# Iteration 10/100001
# 	Avg. Cross-Entropy: 0.2112731
# 	Avg. 100 iterations time: 0.11 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 20/100001
# 	Avg. Cross-Entropy: 0.2108196
# 	Avg. 100 iterations time: 0.11 minutes
# 	Approx. time to completion: 1.86 hours
# Iteration 30/100001
# 	Avg. Cross-Entropy: 0.2130781
# 	Avg. 100 iterations time: 0.11 minutes
# 	Approx. time to completion: 1.82 hours
# Iteration 40/100001
# 	Avg. Cross-Entropy: 0.2332685
# 	Avg. 100 iterations time: 0.12 minutes
# 	Approx. time to completion: 1.98 hours
# Iteration 50/100001
# 	Avg. Cross-Entropy: 0.2191537
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.31 hours
# Iteration 60/100001
# 	Avg. Cross-Entropy: 0.1893231
# 	Avg. 100 iterations time: 0.13 minutes
# 	Approx. time to completion: 2.24 hours
# Iteration 70/100001
# 	Avg. Cross-Entropy: 0.1797196
# 	Avg. 100 iterations time: 0.13 minutes
# 	Approx. time to completion: 2.22 hours
# Iteration 80/100001
# 	Avg. Cross-Entropy: 0.2038008
# 	Avg. 100 iterations time: 0.13 minutes
# 	Approx. time to completion: 2.21 hours
# Iteration 90/100001
# 	Avg. Cross-Entropy: 0.2063198
# 	Avg. 100 iterations time: 0.13 minutes
# 	Approx. time to completion: 2.15 hours
# Iteration 100/100001
# 	Avg. Cross-Entropy: 0.2314600
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.27 hours
# Iteration 110/100001
# 	Avg. Cross-Entropy: 0.2138938
# 	Avg. 100 iterations time: 0.13 minutes
# 	Approx. time to completion: 2.25 hours
# Iteration 120/100001
# 	Avg. Cross-Entropy: 0.1817039
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.28 hours
# Iteration 130/100001
# 	Avg. Cross-Entropy: 0.1948931
# 	Avg. 100 iterations time: 0.13 minutes
# 	Approx. time to completion: 2.24 hours
# Iteration 140/100001
# 	Avg. Cross-Entropy: 0.2274920
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.28 hours
# Iteration 150/100001
# 	Avg. Cross-Entropy: 0.2042157
# 	Avg. 100 iterations time: 0.13 minutes
# 	Approx. time to completion: 2.25 hours
# Iteration 160/100001
# 	Avg. Cross-Entropy: 0.2053461
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.29 hours
# Iteration 170/100001
# 	Avg. Cross-Entropy: 0.1995851
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.34 hours
# Iteration 180/100001
# 	Avg. Cross-Entropy: 0.1923947
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.31 hours
# Iteration 190/100001
# 	Avg. Cross-Entropy: 0.1744317
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.29 hours
# Iteration 200/100001
# 	Avg. Cross-Entropy: 0.1580530
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.28 hours
# Iteration 210/100001
# 	Avg. Cross-Entropy: 0.1652101
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.33 hours
# Iteration 220/100001
# 	Avg. Cross-Entropy: 0.1380294
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.30 hours
# Iteration 230/100001
# 	Avg. Cross-Entropy: 0.1621970
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.30 hours
# Iteration 240/100001
# 	Avg. Cross-Entropy: 0.1978296
# 	Avg. 100 iterations time: 0.14 minutes
# 	Approx. time to completion: 2.33 hours
# Iteration 250/100001
# 	Avg. Cross-Entropy: 0.1442944
# 	Avg. 100 iterations time: 0.15 minutes
# 	Approx. time to completion: 2.42 hours
# Iteration 260/100001
# 	Avg. Cross-Entropy: 0.1322117
# 	Avg. 100 iterations time: 0.15 minutes
# 	Approx. time to completion: 2.44 hours
# Iteration 270/100001
# 	Avg. Cross-Entropy: 0.1727546
# 	Avg. 100 iterations time: 0.15 minutes
# 	Approx. time to completion: 2.46 hours
# Iteration 280/100001
# 	Avg. Cross-Entropy: 0.1545994
# 	Avg. 100 iterations time: 0.15 minutes
# 	Approx. time to completion: 2.49 hours
# Iteration 290/100001
# 	Avg. Cross-Entropy: 0.1666769
# 	Avg. 100 iterations time: 0.15 minutes
# 	Approx. time to completion: 2.47 hours
# Iteration 300/100001
# 	Avg. Cross-Entropy: 0.1743921
# 	Avg. 100 iterations time: 0.15 minutes
# 	Approx. time to completion: 2.55 hours
# Iteration 310/100001
# 	Avg. Cross-Entropy: 0.1489344
# 	Avg. 100 iterations time: 0.15 minutes
# 	Approx. time to completion: 2.55 hours
# Iteration 320/100001
# 	Avg. Cross-Entropy: 0.1336942
# 	Avg. 100 iterations time: 0.15 minutes
# 	Approx. time to completion: 2.53 hours
# Iteration 330/100001
# 	Avg. Cross-Entropy: 0.1435562
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.63 hours
# Iteration 340/100001
# 	Avg. Cross-Entropy: 0.1338844
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 350/100001
# 	Avg. Cross-Entropy: 0.1333005
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 360/100001
# 	Avg. Cross-Entropy: 0.1643051
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 370/100001
# 	Avg. Cross-Entropy: 0.1052028
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.62 hours
# Iteration 380/100001
# 	Avg. Cross-Entropy: 0.0809907
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 390/100001
# 	Avg. Cross-Entropy: 0.1149026
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 400/100001
# 	Avg. Cross-Entropy: 0.1274111
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 410/100001
# 	Avg. Cross-Entropy: 0.1140427
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 420/100001
# 	Avg. Cross-Entropy: 0.1918292
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 430/100001
# 	Avg. Cross-Entropy: 0.1395406
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 440/100001
# 	Avg. Cross-Entropy: 0.1209370
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 450/100001
# 	Avg. Cross-Entropy: 0.0852272
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 460/100001
# 	Avg. Cross-Entropy: 0.1445413
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 470/100001
# 	Avg. Cross-Entropy: 0.0939403
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 480/100001
# 	Avg. Cross-Entropy: 0.0955305
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 490/100001
# 	Avg. Cross-Entropy: 0.1108544
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 500/100001
# 	Avg. Cross-Entropy: 0.1114865
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 510/100001
# 	Avg. Cross-Entropy: 0.1761881
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 520/100001
# 	Avg. Cross-Entropy: 0.1261940
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 530/100001
# 	Avg. Cross-Entropy: 0.0949073
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 540/100001
# 	Avg. Cross-Entropy: 0.0809043
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 550/100001
# 	Avg. Cross-Entropy: 0.0980570
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 560/100001
# 	Avg. Cross-Entropy: 0.0759862
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 570/100001
# 	Avg. Cross-Entropy: 0.0918759
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 580/100001
# 	Avg. Cross-Entropy: 0.0828447
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 590/100001
# 	Avg. Cross-Entropy: 0.0900346
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 600/100001
# 	Avg. Cross-Entropy: 0.0806384
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 610/100001
# 	Avg. Cross-Entropy: 0.0876303
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 620/100001
# 	Avg. Cross-Entropy: 0.0887152
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 630/100001
# 	Avg. Cross-Entropy: 0.0806502
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 640/100001
# 	Avg. Cross-Entropy: 0.0594780
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 650/100001
# 	Avg. Cross-Entropy: 0.0985723
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 660/100001
# 	Avg. Cross-Entropy: 0.0601890
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 670/100001
# 	Avg. Cross-Entropy: 0.0823230
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 680/100001
# 	Avg. Cross-Entropy: 0.0774044
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 690/100001
# 	Avg. Cross-Entropy: 0.0793036
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 700/100001
# 	Avg. Cross-Entropy: 0.0680559
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 710/100001
# 	Avg. Cross-Entropy: 0.0604324
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 720/100001
# 	Avg. Cross-Entropy: 0.0822094
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 730/100001
# 	Avg. Cross-Entropy: 0.0708218
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 740/100001
# 	Avg. Cross-Entropy: 0.0416938
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 750/100001
# 	Avg. Cross-Entropy: 0.0582009
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 760/100001
# 	Avg. Cross-Entropy: 0.0385082
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 770/100001
# 	Avg. Cross-Entropy: 0.0451658
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 780/100001
# 	Avg. Cross-Entropy: 0.0363302
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 790/100001
# 	Avg. Cross-Entropy: 0.0397353
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 800/100001
# 	Avg. Cross-Entropy: 0.0604860
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 810/100001
# 	Avg. Cross-Entropy: 0.0726988
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 820/100001
# 	Avg. Cross-Entropy: 0.1113069
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 830/100001
# 	Avg. Cross-Entropy: 0.0894382
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 840/100001
# 	Avg. Cross-Entropy: 0.0544308
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 850/100001
# 	Avg. Cross-Entropy: 0.0477228
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.73 hours
# Iteration 860/100001
# 	Avg. Cross-Entropy: 0.0545441
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.73 hours
# Iteration 870/100001
# 	Avg. Cross-Entropy: 0.0391081
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.74 hours
# Iteration 880/100001
# 	Avg. Cross-Entropy: 0.0418907
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.75 hours
# Iteration 890/100001
# 	Avg. Cross-Entropy: 0.0409032
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.74 hours
# Iteration 900/100001
# 	Avg. Cross-Entropy: 0.0518756
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.74 hours
# Iteration 910/100001
# 	Avg. Cross-Entropy: 0.0506670
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.75 hours
# Iteration 920/100001
# 	Avg. Cross-Entropy: 0.0308030
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.75 hours
# Iteration 930/100001
# 	Avg. Cross-Entropy: 0.0408864
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.74 hours
# Iteration 940/100001
# 	Avg. Cross-Entropy: 0.0233004
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.73 hours
# Iteration 950/100001
# 	Avg. Cross-Entropy: 0.0366635
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 960/100001
# 	Avg. Cross-Entropy: 0.0304551
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 970/100001
# 	Avg. Cross-Entropy: 0.0366738
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 980/100001
# 	Avg. Cross-Entropy: 0.0233888
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.73 hours
# Iteration 990/100001
# 	Avg. Cross-Entropy: 0.0536122
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.73 hours
# Iteration 1000/100001
# 	Avg. Cross-Entropy: 0.0269295
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.72 hours
#
# Saving Checkpoint ... Done!
# Iteration 1010/100001
# 	Avg. Cross-Entropy: 0.0207784
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1020/100001
# 	Avg. Cross-Entropy: 0.0423945
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1030/100001
# 	Avg. Cross-Entropy: 0.0594066
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.73 hours
# Iteration 1040/100001
# 	Avg. Cross-Entropy: 0.0693678
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.73 hours
# Iteration 1050/100001
# 	Avg. Cross-Entropy: 0.0217774
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1060/100001
# 	Avg. Cross-Entropy: 0.0211533
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1070/100001
# 	Avg. Cross-Entropy: 0.0189259
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1080/100001
# 	Avg. Cross-Entropy: 0.0483084
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1090/100001
# 	Avg. Cross-Entropy: 0.0358068
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1100/100001
# 	Avg. Cross-Entropy: 0.0466811
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1110/100001
# 	Avg. Cross-Entropy: 0.0315178
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1120/100001
# 	Avg. Cross-Entropy: 0.0380566
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1130/100001
# 	Avg. Cross-Entropy: 0.0224844
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1140/100001
# 	Avg. Cross-Entropy: 0.0316021
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1150/100001
# 	Avg. Cross-Entropy: 0.0668434
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1160/100001
# 	Avg. Cross-Entropy: 0.0408898
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1170/100001
# 	Avg. Cross-Entropy: 0.0223869
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1180/100001
# 	Avg. Cross-Entropy: 0.0241438
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1190/100001
# 	Avg. Cross-Entropy: 0.0146849
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1200/100001
# 	Avg. Cross-Entropy: 0.0331949
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1210/100001
# 	Avg. Cross-Entropy: 0.0386988
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1220/100001
# 	Avg. Cross-Entropy: 0.0159954
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1230/100001
# 	Avg. Cross-Entropy: 0.0309571
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1240/100001
# 	Avg. Cross-Entropy: 0.0492334
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1250/100001
# 	Avg. Cross-Entropy: 0.0284773
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1260/100001
# 	Avg. Cross-Entropy: 0.0311521
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1270/100001
# 	Avg. Cross-Entropy: 0.0184571
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1280/100001
# 	Avg. Cross-Entropy: 0.0615197
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1290/100001
# 	Avg. Cross-Entropy: 0.0147908
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1300/100001
# 	Avg. Cross-Entropy: 0.0149261
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1310/100001
# 	Avg. Cross-Entropy: 0.0193391
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1320/100001
# 	Avg. Cross-Entropy: 0.0155406
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1330/100001
# 	Avg. Cross-Entropy: 0.0262380
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1340/100001
# 	Avg. Cross-Entropy: 0.0157123
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1350/100001
# 	Avg. Cross-Entropy: 0.0168627
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1360/100001
# 	Avg. Cross-Entropy: 0.0297664
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1370/100001
# 	Avg. Cross-Entropy: 0.0201985
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1380/100001
# 	Avg. Cross-Entropy: 0.0325252
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1390/100001
# 	Avg. Cross-Entropy: 0.0165223
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1400/100001
# 	Avg. Cross-Entropy: 0.0357897
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1410/100001
# 	Avg. Cross-Entropy: 0.0160780
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1420/100001
# 	Avg. Cross-Entropy: 0.0279286
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1430/100001
# 	Avg. Cross-Entropy: 0.0359814
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1440/100001
# 	Avg. Cross-Entropy: 0.0320425
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1450/100001
# 	Avg. Cross-Entropy: 0.0532326
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1460/100001
# 	Avg. Cross-Entropy: 0.0406621
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1470/100001
# 	Avg. Cross-Entropy: 0.0184921
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1480/100001
# 	Avg. Cross-Entropy: 0.0342328
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1490/100001
# 	Avg. Cross-Entropy: 0.0281781
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1500/100001
# 	Avg. Cross-Entropy: 0.0281665
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1510/100001
# 	Avg. Cross-Entropy: 0.0351276
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1520/100001
# 	Avg. Cross-Entropy: 0.0524952
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1530/100001
# 	Avg. Cross-Entropy: 0.0169795
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1540/100001
# 	Avg. Cross-Entropy: 0.0111723
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1550/100001
# 	Avg. Cross-Entropy: 0.0151535
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1560/100001
# 	Avg. Cross-Entropy: 0.0084488
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1570/100001
# 	Avg. Cross-Entropy: 0.0220741
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1580/100001
# 	Avg. Cross-Entropy: 0.0277446
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1590/100001
# 	Avg. Cross-Entropy: 0.0114073
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1600/100001
# 	Avg. Cross-Entropy: 0.0325029
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1610/100001
# 	Avg. Cross-Entropy: 0.0233242
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1620/100001
# 	Avg. Cross-Entropy: 0.0120800
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1630/100001
# 	Avg. Cross-Entropy: 0.0382205
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.72 hours
# Iteration 1640/100001
# 	Avg. Cross-Entropy: 0.0271545
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1650/100001
# 	Avg. Cross-Entropy: 0.0248622
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1660/100001
# 	Avg. Cross-Entropy: 0.0154374
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1670/100001
# 	Avg. Cross-Entropy: 0.0262434
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 1680/100001
# 	Avg. Cross-Entropy: 0.0206291
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1690/100001
# 	Avg. Cross-Entropy: 0.0123102
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1700/100001
# 	Avg. Cross-Entropy: 0.0352459
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1710/100001
# 	Avg. Cross-Entropy: 0.0155827
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1720/100001
# 	Avg. Cross-Entropy: 0.0317633
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1730/100001
# 	Avg. Cross-Entropy: 0.0230419
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1740/100001
# 	Avg. Cross-Entropy: 0.0116942
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1750/100001
# 	Avg. Cross-Entropy: 0.0327073
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1760/100001
# 	Avg. Cross-Entropy: 0.0110067
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1770/100001
# 	Avg. Cross-Entropy: 0.0104773
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1780/100001
# 	Avg. Cross-Entropy: 0.0376188
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1790/100001
# 	Avg. Cross-Entropy: 0.0133370
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1800/100001
# 	Avg. Cross-Entropy: 0.0326481
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1810/100001
# 	Avg. Cross-Entropy: 0.0281336
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1820/100001
# 	Avg. Cross-Entropy: 0.0242242
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1830/100001
# 	Avg. Cross-Entropy: 0.0085785
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1840/100001
# 	Avg. Cross-Entropy: 0.0491442
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1850/100001
# 	Avg. Cross-Entropy: 0.0114054
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1860/100001
# 	Avg. Cross-Entropy: 0.0198271
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1870/100001
# 	Avg. Cross-Entropy: 0.0302556
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1880/100001
# 	Avg. Cross-Entropy: 0.0080709
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1890/100001
# 	Avg. Cross-Entropy: 0.0214165
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1900/100001
# 	Avg. Cross-Entropy: 0.0301706
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1910/100001
# 	Avg. Cross-Entropy: 0.0135547
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1920/100001
# 	Avg. Cross-Entropy: 0.0113651
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1930/100001
# 	Avg. Cross-Entropy: 0.0176479
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1940/100001
# 	Avg. Cross-Entropy: 0.0240120
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1950/100001
# 	Avg. Cross-Entropy: 0.0203945
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1960/100001
# 	Avg. Cross-Entropy: 0.0228378
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1970/100001
# 	Avg. Cross-Entropy: 0.0125389
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 1980/100001
# 	Avg. Cross-Entropy: 0.0233465
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 1990/100001
# 	Avg. Cross-Entropy: 0.0092591
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2000/100001
# 	Avg. Cross-Entropy: 0.0442705
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
#
# Saving Checkpoint ... Done!
# Iteration 2010/100001
# 	Avg. Cross-Entropy: 0.0251698
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 2020/100001
# 	Avg. Cross-Entropy: 0.0151811
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 2030/100001
# 	Avg. Cross-Entropy: 0.0215243
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2040/100001
# 	Avg. Cross-Entropy: 0.0436016
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 2050/100001
# 	Avg. Cross-Entropy: 0.0244139
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2060/100001
# 	Avg. Cross-Entropy: 0.0276423
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.71 hours
# Iteration 2070/100001
# 	Avg. Cross-Entropy: 0.0186998
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2080/100001
# 	Avg. Cross-Entropy: 0.0344092
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2090/100001
# 	Avg. Cross-Entropy: 0.0050302
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2100/100001
# 	Avg. Cross-Entropy: 0.0182021
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2110/100001
# 	Avg. Cross-Entropy: 0.0215839
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2120/100001
# 	Avg. Cross-Entropy: 0.0127619
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2130/100001
# 	Avg. Cross-Entropy: 0.0103721
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2140/100001
# 	Avg. Cross-Entropy: 0.0349360
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2150/100001
# 	Avg. Cross-Entropy: 0.0095550
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2160/100001
# 	Avg. Cross-Entropy: 0.0116147
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2170/100001
# 	Avg. Cross-Entropy: 0.0180415
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2180/100001
# 	Avg. Cross-Entropy: 0.0080365
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2190/100001
# 	Avg. Cross-Entropy: 0.0265430
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2200/100001
# 	Avg. Cross-Entropy: 0.0113686
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2210/100001
# 	Avg. Cross-Entropy: 0.0110547
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2220/100001
# 	Avg. Cross-Entropy: 0.0234717
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2230/100001
# 	Avg. Cross-Entropy: 0.0179774
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2240/100001
# 	Avg. Cross-Entropy: 0.0153318
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2250/100001
# 	Avg. Cross-Entropy: 0.0096354
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2260/100001
# 	Avg. Cross-Entropy: 0.0280714
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2270/100001
# 	Avg. Cross-Entropy: 0.0147365
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2280/100001
# 	Avg. Cross-Entropy: 0.0171702
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2290/100001
# 	Avg. Cross-Entropy: 0.0063183
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2300/100001
# 	Avg. Cross-Entropy: 0.0378737
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2310/100001
# 	Avg. Cross-Entropy: 0.0119167
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2320/100001
# 	Avg. Cross-Entropy: 0.0240701
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2330/100001
# 	Avg. Cross-Entropy: 0.0218199
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2340/100001
# 	Avg. Cross-Entropy: 0.0043650
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2350/100001
# 	Avg. Cross-Entropy: 0.0072684
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2360/100001
# 	Avg. Cross-Entropy: 0.0102691
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2370/100001
# 	Avg. Cross-Entropy: 0.0130899
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2380/100001
# 	Avg. Cross-Entropy: 0.0169770
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2390/100001
# 	Avg. Cross-Entropy: 0.0075078
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2400/100001
# 	Avg. Cross-Entropy: 0.0173477
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2410/100001
# 	Avg. Cross-Entropy: 0.0206070
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.70 hours
# Iteration 2420/100001
# 	Avg. Cross-Entropy: 0.0061854
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2430/100001
# 	Avg. Cross-Entropy: 0.0129489
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2440/100001
# 	Avg. Cross-Entropy: 0.0057352
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2450/100001
# 	Avg. Cross-Entropy: 0.0194825
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 2460/100001
# 	Avg. Cross-Entropy: 0.0206910
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2470/100001
# 	Avg. Cross-Entropy: 0.0231103
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2480/100001
# 	Avg. Cross-Entropy: 0.0165458
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2490/100001
# 	Avg. Cross-Entropy: 0.0127038
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2500/100001
# 	Avg. Cross-Entropy: 0.0116124
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2510/100001
# 	Avg. Cross-Entropy: 0.0080525
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2520/100001
# 	Avg. Cross-Entropy: 0.0097861
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2530/100001
# 	Avg. Cross-Entropy: 0.0154500
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2540/100001
# 	Avg. Cross-Entropy: 0.0046555
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2550/100001
# 	Avg. Cross-Entropy: 0.0211436
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2560/100001
# 	Avg. Cross-Entropy: 0.0094171
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2570/100001
# 	Avg. Cross-Entropy: 0.0203086
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2580/100001
# 	Avg. Cross-Entropy: 0.0081661
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2590/100001
# 	Avg. Cross-Entropy: 0.0090704
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2600/100001
# 	Avg. Cross-Entropy: 0.0087973
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2610/100001
# 	Avg. Cross-Entropy: 0.0056304
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2620/100001
# 	Avg. Cross-Entropy: 0.0062125
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2630/100001
# 	Avg. Cross-Entropy: 0.0061950
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2640/100001
# 	Avg. Cross-Entropy: 0.0169556
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2650/100001
# 	Avg. Cross-Entropy: 0.0076466
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2660/100001
# 	Avg. Cross-Entropy: 0.0201893
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2670/100001
# 	Avg. Cross-Entropy: 0.0066738
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2680/100001
# 	Avg. Cross-Entropy: 0.0096072
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2690/100001
# 	Avg. Cross-Entropy: 0.0029086
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2700/100001
# 	Avg. Cross-Entropy: 0.0181893
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2710/100001
# 	Avg. Cross-Entropy: 0.0051697
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2720/100001
# 	Avg. Cross-Entropy: 0.0130051
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2730/100001
# 	Avg. Cross-Entropy: 0.0256694
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2740/100001
# 	Avg. Cross-Entropy: 0.0262810
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2750/100001
# 	Avg. Cross-Entropy: 0.0092295
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2760/100001
# 	Avg. Cross-Entropy: 0.0061681
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 2770/100001
# 	Avg. Cross-Entropy: 0.0111839
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2780/100001
# 	Avg. Cross-Entropy: 0.0130057
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2790/100001
# 	Avg. Cross-Entropy: 0.0296041
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2800/100001
# 	Avg. Cross-Entropy: 0.0053003
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2810/100001
# 	Avg. Cross-Entropy: 0.0154493
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2820/100001
# 	Avg. Cross-Entropy: 0.0086717
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 2830/100001
# 	Avg. Cross-Entropy: 0.0095237
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2840/100001
# 	Avg. Cross-Entropy: 0.0225635
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2850/100001
# 	Avg. Cross-Entropy: 0.0096516
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2860/100001
# 	Avg. Cross-Entropy: 0.0047260
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2870/100001
# 	Avg. Cross-Entropy: 0.0050593
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2880/100001
# 	Avg. Cross-Entropy: 0.0055624
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2890/100001
# 	Avg. Cross-Entropy: 0.0210367
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2900/100001
# 	Avg. Cross-Entropy: 0.0093730
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2910/100001
# 	Avg. Cross-Entropy: 0.0144850
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2920/100001
# 	Avg. Cross-Entropy: 0.0191544
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2930/100001
# 	Avg. Cross-Entropy: 0.0075470
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 2940/100001
# 	Avg. Cross-Entropy: 0.0062676
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 2950/100001
# 	Avg. Cross-Entropy: 0.0060304
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 2960/100001
# 	Avg. Cross-Entropy: 0.0055261
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 2970/100001
# 	Avg. Cross-Entropy: 0.0132093
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2980/100001
# 	Avg. Cross-Entropy: 0.0091552
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 2990/100001
# 	Avg. Cross-Entropy: 0.0065864
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 3000/100001
# 	Avg. Cross-Entropy: 0.0140298
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.67 hours
#
# Saving Checkpoint ... Done!
# Iteration 3010/100001
# 	Avg. Cross-Entropy: 0.0108786
# 	Avg. 100 iterations time: 0.16 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 3020/100001
# 	Avg. Cross-Entropy: 0.0155764
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3030/100001
# 	Avg. Cross-Entropy: 0.0085773
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3040/100001
# 	Avg. Cross-Entropy: 0.0043558
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3050/100001
# 	Avg. Cross-Entropy: 0.0073764
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3060/100001
# 	Avg. Cross-Entropy: 0.0047058
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3070/100001
# 	Avg. Cross-Entropy: 0.0064111
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3080/100001
# 	Avg. Cross-Entropy: 0.0132756
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3090/100001
# 	Avg. Cross-Entropy: 0.0061687
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3100/100001
# 	Avg. Cross-Entropy: 0.0063897
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3110/100001
# 	Avg. Cross-Entropy: 0.0070815
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3120/100001
# 	Avg. Cross-Entropy: 0.0166380
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.66 hours
# Iteration 3130/100001
# 	Avg. Cross-Entropy: 0.0046757
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3140/100001
# 	Avg. Cross-Entropy: 0.0163004
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3150/100001
# 	Avg. Cross-Entropy: 0.0120479
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3160/100001
# 	Avg. Cross-Entropy: 0.0101492
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3170/100001
# 	Avg. Cross-Entropy: 0.0149049
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3180/100001
# 	Avg. Cross-Entropy: 0.0146686
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3190/100001
# 	Avg. Cross-Entropy: 0.0065179
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3200/100001
# 	Avg. Cross-Entropy: 0.0077950
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3210/100001
# 	Avg. Cross-Entropy: 0.0045079
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3220/100001
# 	Avg. Cross-Entropy: 0.0101677
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3230/100001
# 	Avg. Cross-Entropy: 0.0083064
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3240/100001
# 	Avg. Cross-Entropy: 0.0074281
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3250/100001
# 	Avg. Cross-Entropy: 0.0053636
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3260/100001
# 	Avg. Cross-Entropy: 0.0049292
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3270/100001
# 	Avg. Cross-Entropy: 0.0131173
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3280/100001
# 	Avg. Cross-Entropy: 0.0080422
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3290/100001
# 	Avg. Cross-Entropy: 0.0038164
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3300/100001
# 	Avg. Cross-Entropy: 0.0064050
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3310/100001
# 	Avg. Cross-Entropy: 0.0231348
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3320/100001
# 	Avg. Cross-Entropy: 0.0045563
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3330/100001
# 	Avg. Cross-Entropy: 0.0063895
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3340/100001
# 	Avg. Cross-Entropy: 0.0081678
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3350/100001
# 	Avg. Cross-Entropy: 0.0072662
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3360/100001
# 	Avg. Cross-Entropy: 0.0054407
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3370/100001
# 	Avg. Cross-Entropy: 0.0246624
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3380/100001
# 	Avg. Cross-Entropy: 0.0050229
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3390/100001
# 	Avg. Cross-Entropy: 0.0035436
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3400/100001
# 	Avg. Cross-Entropy: 0.0159171
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.67 hours
# Iteration 3410/100001
# 	Avg. Cross-Entropy: 0.0024200
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.68 hours
# Iteration 3420/100001
# 	Avg. Cross-Entropy: 0.0048632
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 3430/100001
# 	Avg. Cross-Entropy: 0.0040503
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 3440/100001
# 	Avg. Cross-Entropy: 0.0056158
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 3450/100001
# 	Avg. Cross-Entropy: 0.0117110
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 3460/100001
# 	Avg. Cross-Entropy: 0.0053446
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 3470/100001
# 	Avg. Cross-Entropy: 0.0182137
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 3480/100001
# 	Avg. Cross-Entropy: 0.0049045
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 3490/100001
# 	Avg. Cross-Entropy: 0.0124196
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 3500/100001
# 	Avg. Cross-Entropy: 0.0069488
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 3510/100001
# 	Avg. Cross-Entropy: 0.0047181
# 	Avg. 100 iterations time: 0.17 minutes
# 	Approx. time to completion: 2.69 hours
# Iteration 3520/100001
# ...
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35490/100001
# 	Avg. Cross-Entropy: 0.0020397
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35500/100001
# 	Avg. Cross-Entropy: 0.0015755
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35510/100001
# 	Avg. Cross-Entropy: 0.0027973
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35520/100001
# 	Avg. Cross-Entropy: 0.0014419
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35530/100001
# 	Avg. Cross-Entropy: 0.0018826
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35540/100001
# 	Avg. Cross-Entropy: 0.0022308
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35550/100001
# 	Avg. Cross-Entropy: 0.0011249
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35560/100001
# 	Avg. Cross-Entropy: 0.0016458
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35570/100001
# 	Avg. Cross-Entropy: 0.0020663
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35580/100001
# 	Avg. Cross-Entropy: 0.0025371
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35590/100001
# 	Avg. Cross-Entropy: 0.0018047
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35600/100001
# 	Avg. Cross-Entropy: 0.0026129
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35610/100001
# 	Avg. Cross-Entropy: 0.0012785
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35620/100001
# 	Avg. Cross-Entropy: 0.0014047
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35630/100001
# 	Avg. Cross-Entropy: 0.0017801
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35640/100001
# 	Avg. Cross-Entropy: 0.0018839
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35650/100001
# 	Avg. Cross-Entropy: 0.0019362
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35660/100001
# 	Avg. Cross-Entropy: 0.0016564
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35670/100001
# 	Avg. Cross-Entropy: 0.0027297
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35680/100001
# 	Avg. Cross-Entropy: 0.0019507
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35690/100001
# 	Avg. Cross-Entropy: 0.0022804
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35700/100001
# 	Avg. Cross-Entropy: 0.0015758
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35710/100001
# 	Avg. Cross-Entropy: 0.0011067
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35720/100001
# 	Avg. Cross-Entropy: 0.0028383
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35730/100001
# 	Avg. Cross-Entropy: 0.0014989
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35740/100001
# 	Avg. Cross-Entropy: 0.0028961
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35750/100001
# 	Avg. Cross-Entropy: 0.0014633
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35760/100001
# 	Avg. Cross-Entropy: 0.0014587
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35770/100001
# 	Avg. Cross-Entropy: 0.0010845
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35780/100001
# 	Avg. Cross-Entropy: 0.0026081
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35790/100001
# 	Avg. Cross-Entropy: 0.0028845
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35800/100001
# 	Avg. Cross-Entropy: 0.0046804
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.93 hours
# Iteration 35810/100001
# 	Avg. Cross-Entropy: 0.0017006
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35820/100001
# 	Avg. Cross-Entropy: 0.0010988
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35830/100001
# 	Avg. Cross-Entropy: 0.0018345
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35840/100001
# 	Avg. Cross-Entropy: 0.0023853
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35850/100001
# 	Avg. Cross-Entropy: 0.0016397
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35860/100001
# 	Avg. Cross-Entropy: 0.0019790
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35870/100001
# 	Avg. Cross-Entropy: 0.0023253
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35880/100001
# 	Avg. Cross-Entropy: 0.0017519
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35890/100001
# 	Avg. Cross-Entropy: 0.0011564
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35900/100001
# 	Avg. Cross-Entropy: 0.0010034
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35910/100001
# 	Avg. Cross-Entropy: 0.0020856
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35920/100001
# 	Avg. Cross-Entropy: 0.0027799
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35930/100001
# 	Avg. Cross-Entropy: 0.0008910
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35940/100001
# 	Avg. Cross-Entropy: 0.0013947
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35950/100001
# 	Avg. Cross-Entropy: 0.0022785
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35960/100001
# 	Avg. Cross-Entropy: 0.0020451
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35970/100001
# 	Avg. Cross-Entropy: 0.0023897
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35980/100001
# 	Avg. Cross-Entropy: 0.0023452
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 35990/100001
# 	Avg. Cross-Entropy: 0.0013858
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36000/100001
# 	Avg. Cross-Entropy: 0.0021782
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
#
# Saving Checkpoint ... Done!
# Iteration 36010/100001
# 	Avg. Cross-Entropy: 0.0017201
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36020/100001
# 	Avg. Cross-Entropy: 0.0022851
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36030/100001
# 	Avg. Cross-Entropy: 0.0023185
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36040/100001
# 	Avg. Cross-Entropy: 0.0019748
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36050/100001
# 	Avg. Cross-Entropy: 0.0013345
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36060/100001
# 	Avg. Cross-Entropy: 0.0019750
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36070/100001
# 	Avg. Cross-Entropy: 0.0014131
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36080/100001
# 	Avg. Cross-Entropy: 0.0014698
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36090/100001
# 	Avg. Cross-Entropy: 0.0016191
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36100/100001
# 	Avg. Cross-Entropy: 0.0025542
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36110/100001
# 	Avg. Cross-Entropy: 0.0018593
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36120/100001
# 	Avg. Cross-Entropy: 0.0017998
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.92 hours
# Iteration 36130/100001
# 	Avg. Cross-Entropy: 0.0018207
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36140/100001
# 	Avg. Cross-Entropy: 0.0016114
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36150/100001
# 	Avg. Cross-Entropy: 0.0013377
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36160/100001
# 	Avg. Cross-Entropy: 0.0014931
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36170/100001
# 	Avg. Cross-Entropy: 0.0020396
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36180/100001
# 	Avg. Cross-Entropy: 0.0012695
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36190/100001
# 	Avg. Cross-Entropy: 0.0030277
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36200/100001
# 	Avg. Cross-Entropy: 0.0015230
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36210/100001
# 	Avg. Cross-Entropy: 0.0028588
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36220/100001
# 	Avg. Cross-Entropy: 0.0024064
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36230/100001
# 	Avg. Cross-Entropy: 0.0020895
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36240/100001
# 	Avg. Cross-Entropy: 0.0016108
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36250/100001
# 	Avg. Cross-Entropy: 0.0008874
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36260/100001
# 	Avg. Cross-Entropy: 0.0015740
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36270/100001
# 	Avg. Cross-Entropy: 0.0016033
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36280/100001
# 	Avg. Cross-Entropy: 0.0014806
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36290/100001
# 	Avg. Cross-Entropy: 0.0012366
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36300/100001
# 	Avg. Cross-Entropy: 0.0019198
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36310/100001
# 	Avg. Cross-Entropy: 0.0014628
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36320/100001
# 	Avg. Cross-Entropy: 0.0012123
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36330/100001
# 	Avg. Cross-Entropy: 0.0019815
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36340/100001
# 	Avg. Cross-Entropy: 0.0014947
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36350/100001
# 	Avg. Cross-Entropy: 0.0019766
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36360/100001
# 	Avg. Cross-Entropy: 0.0015810
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36370/100001
# 	Avg. Cross-Entropy: 0.0021352
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36380/100001
# 	Avg. Cross-Entropy: 0.0031296
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36390/100001
# 	Avg. Cross-Entropy: 0.0018309
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36400/100001
# 	Avg. Cross-Entropy: 0.0031285
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36410/100001
# 	Avg. Cross-Entropy: 0.0013819
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36420/100001
# 	Avg. Cross-Entropy: 0.0017567
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36430/100001
# 	Avg. Cross-Entropy: 0.0021356
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.91 hours
# Iteration 36440/100001
# 	Avg. Cross-Entropy: 0.0024598
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36450/100001
# 	Avg. Cross-Entropy: 0.0018788
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36460/100001
# 	Avg. Cross-Entropy: 0.0024856
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36470/100001
# 	Avg. Cross-Entropy: 0.0020645
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36480/100001
# 	Avg. Cross-Entropy: 0.0017320
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36490/100001
# 	Avg. Cross-Entropy: 0.0010169
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36500/100001
# 	Avg. Cross-Entropy: 0.0016806
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36510/100001
# 	Avg. Cross-Entropy: 0.0028349
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36520/100001
# 	Avg. Cross-Entropy: 0.0015778
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36530/100001
# 	Avg. Cross-Entropy: 0.0012679
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36540/100001
# 	Avg. Cross-Entropy: 0.0024436
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36550/100001
# 	Avg. Cross-Entropy: 0.0010442
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36560/100001
# 	Avg. Cross-Entropy: 0.0009474
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36570/100001
# 	Avg. Cross-Entropy: 0.0017851
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36580/100001
# 	Avg. Cross-Entropy: 0.0025898
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36590/100001
# 	Avg. Cross-Entropy: 0.0021319
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36600/100001
# 	Avg. Cross-Entropy: 0.0020416
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36610/100001
# 	Avg. Cross-Entropy: 0.0019696
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36620/100001
# 	Avg. Cross-Entropy: 0.0023164
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36630/100001
# 	Avg. Cross-Entropy: 0.0015826
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36640/100001
# 	Avg. Cross-Entropy: 0.0024576
# 	Avg. 100 iterations time: 0.18 minutes
# 	Approx. time to completion: 1.90 hours
# Iteration 36643/100001
# Saving Checkpoint ... Done!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Output Training Weights

# %%
print(next(os.walk(ckpts_dir))[1])
# Out:
# ['step-27000', 'step-18000', 'step-3000', 'step-4000', 'step-19000', 'step-10000', 'step-12000', 'step-20000', 'step-1000', 'step-33000', 'step-21000', 'step-5000', 'step-32000', 'step-17000', 'step-9000', 'step-22000', 'step-34000', 'step-24000', 'step-29000', 'step-6000', 'step-25000', 'step-7000', 'step-14000', 'step-500005', 'step-35000', 'step-23000', 'step-13000', 'step-15000', 'step-28000', 'step-8000', 'step-16000', 'step-26000', 'step-31000', 'step-30000', 'step-11000', 'step-2000', 'step-36000', 'step-36643']

# %%
ckpts_dir
# Out:
# './dnc-py3/tasks/babi/checkpoints'

# %%
# !zip -r step ./dnc-py3/tasks/babi/checkpoints/*
# Out:
#   adding: dnc-py3/tasks/babi/checkpoints/step-1000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-1000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-1000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-1000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-1000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-10000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-10000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-10000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-10000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-10000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-11000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-11000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-11000/model.ckpt.index (deflated 30%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-11000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-11000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-12000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-12000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-12000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-12000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-12000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-13000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-13000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-13000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-13000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-13000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-14000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-14000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-14000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-14000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-14000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-15000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-15000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-15000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-15000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-15000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-16000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-16000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-16000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-16000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-16000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-17000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-17000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-17000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-17000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-17000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-18000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-18000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-18000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-18000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-18000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-19000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-19000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-19000/model.ckpt.index (deflated 30%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-19000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-19000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-2000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-2000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-2000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-2000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-2000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-20000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-20000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-20000/model.ckpt.index (deflated 30%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-20000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-20000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-21000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-21000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-21000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-21000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-21000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-22000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-22000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-22000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-22000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-22000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-23000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-23000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-23000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-23000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-23000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-24000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-24000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-24000/model.ckpt.index (deflated 30%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-24000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-24000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-25000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-25000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-25000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-25000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-25000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-26000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-26000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-26000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-26000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-26000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-27000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-27000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-27000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-27000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-27000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-28000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-28000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-28000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-28000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-28000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-29000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-29000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-29000/model.ckpt.index (deflated 30%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-29000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-29000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-3000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-3000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-3000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-3000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-3000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-30000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-30000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-30000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-30000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-30000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-31000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-31000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-31000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-31000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-31000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-32000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-32000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-32000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-32000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-32000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-33000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-33000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-33000/model.ckpt.index (deflated 30%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-33000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-33000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-34000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-34000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-34000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-34000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-34000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-35000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-35000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-35000/model.ckpt.index (deflated 30%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-35000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-35000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-36000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-36000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-36000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-36000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-36000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-36643/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-36643/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-36643/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-36643/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-36643/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-4000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-4000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-4000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-4000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-4000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-5000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-5000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-5000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-5000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-5000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-500005/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-500005/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-500005/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-500005/model.ckpt (deflated 8%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-6000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-6000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-6000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-6000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-6000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-7000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-7000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-7000/model.ckpt.index (deflated 29%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-7000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-7000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-8000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-8000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-8000/model.ckpt.index (deflated 30%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-8000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-8000/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-9000/ (stored 0%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-9000/model.ckpt.meta (deflated 94%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-9000/model.ckpt.index (deflated 30%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-9000/checkpoint (deflated 42%)
#   adding: dnc-py3/tasks/babi/checkpoints/step-9000/model.ckpt.data-00000-of-00001 (deflated 7%)
